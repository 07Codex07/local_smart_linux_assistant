# %% [markdown]
# <a href="https://colab.research.google.com/github/07Codex07/local_smart_linux_assistant/blob/main/linux_phi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q transformers accelerate peft bitsandbytes datasets trl
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 MB 10.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 376.2/376.2 kB 21.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 494.8/494.8 kB 30.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 11.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 38.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 25.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 34.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.9 MB/s eta 0:00:00
# ...

# %%
# !pip install -q "fsspec==2025.3.2" "gcsfs==2025.3.2" --upgrade --force-reinstall
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.9/73.9 kB 570.9 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 7.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.1/216.1 kB 15.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.1/176.1 kB 13.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.8/64.8 kB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.8/63.8 kB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.7/162.7 kB 13.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.3/147.3 kB 12.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.3/235.3 kB 16.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.8/160.8 kB 12.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.4/70.4 kB 5.2 MB/s eta 0:00:00
# ...

# %%
pip install -U bitsandbytes
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 MB 11.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 125.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 89.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 58.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 923.0 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 101.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
pip install -U transformers datasets accelerate peft trl bitsandbytes
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 494.8/494.8 kB 28.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 367.1/367.1 kB 27.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 376.2/376.2 kB 27.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 MB 13.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 16.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 106.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 78.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 49.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.4 MB/s eta 0:00:00
# ...

# %%
from datasets import Dataset
import json

# Load your custom dataset
with open("phi2_linux_prompt_dataset.json", "r") as f:
    data = json.load(f)

# Format for training
dataset = Dataset.from_list([
    {
        "text": f"### Human:\n{item['prompt']}\n\n### Assistant:\n{item['response']}"
    }
    for item in data
])

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
from peft import LoraConfig, get_peft_model

model_name = "microsoft/phi-2"

# Load tokenizer and set pad_token
tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer.pad_token = tokenizer.eos_token

# Load model on CPU
model = AutoModelForCausalLM.from_pretrained(model_name)

# Configure LoRA
lora_config = LoraConfig(
    r=8,
    lora_alpha=16,
    target_modules=["q_proj", "v_proj"],
    lora_dropout=0.05,
    bias="none",
    task_type="CAUSAL_LM"
)

# Apply LoRA
model = get_peft_model(model, lora_config)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/99.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/735 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# ...

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
from peft import prepare_model_for_kbit_training, LoraConfig, get_peft_model

model_name = "microsoft/phi-2"
tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer.pad_token = tokenizer.eos_token

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map="auto",
    load_in_4bit=True
)

model = prepare_model_for_kbit_training(model)

lora_config = LoraConfig(
    r=8,
    lora_alpha=16,
    target_modules=["q_proj", "v_proj"],
    lora_dropout=0.05,
    bias="none",
    task_type="CAUSAL_LM"
)

model = get_peft_model(model, lora_config)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
# %pip install -q trl
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 376.2/376.2 kB 10.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 494.8/494.8 kB 29.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 19.3 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.3.0 which is incompatible.

# %%
# !pip uninstall -y fsspec gcsfs
# !pip install fsspec==2025.3.0 gcsfs==2025.3.0 trl datasets
# Out:
# Found existing installation: fsspec 2025.3.0
# Uninstalling fsspec-2025.3.0:
#   Successfully uninstalled fsspec-2025.3.0
# Found existing installation: gcsfs 2025.3.2
# Uninstalling gcsfs-2025.3.2:
#   Successfully uninstalled gcsfs-2025.3.2
# ...
#   Using cached fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# ...
# Using cached fsspec-2025.3.0-py3-none-any.whl (193 kB)
# ...

# %%
pip install -U trl

# %%
from trl import SFTTrainer
from transformers import TrainingArguments, DataCollatorForLanguageModeling

# Define data collator
data_collator = DataCollatorForLanguageModeling(
    tokenizer=tokenizer,
    mlm=False,  # Set to True if you're doing Masked LM like BERT
)

# Define training arguments
training_args = TrainingArguments(
    output_dir="./phi2-finetuned",
    per_device_train_batch_size=4,
    gradient_accumulation_steps=2,
    num_train_epochs=3,
    save_steps=100,
    logging_steps=10,
    learning_rate=2e-5,
    weight_decay=0.01,
    fp16=True,
    save_total_limit=2,
)

# Initialize trainer
trainer = SFTTrainer(
    model=model,
    train_dataset=tokenized_dataset,
    args=training_args,
    data_collator=data_collator
)
# Out:
# Truncating train dataset:   0%|          | 0/100 [00:00<?, ? examples/s]
# No label_names provided for model class `PeftModelForCausalLM`. Since `PeftModel` hides base models input arguments, if label_names is not given, label_names can't be set automatically within `Trainer`. Note that empty label_names list will be used instead.

# %%
from datasets import load_dataset
from transformers import AutoTokenizer

# Load dataset
dataset = load_dataset("json", data_files={"train": "phi2_linux_prompt_dataset.json"})

# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained("microsoft/phi-2")

# Fix: set pad_token if missing
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token if tokenizer.eos_token else tokenizer.add_special_tokens({'pad_token': '[PAD]'})

# Define tokenization
def tokenize_function(examples):
    texts = [f"Prompt: {p}\nResponse: {r}" for p, r in zip(examples["prompt"], examples["response"])]
    return tokenizer(texts, padding="max_length", truncation=True, max_length=512)

# Apply tokenization
tokenized_dataset = dataset["train"].map(tokenize_function, batched=True)
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Map:   0%|          | 0/100 [00:00<?, ? examples/s]

# %%
from datasets import load_dataset
from transformers import AutoTokenizer

# Load dataset
dataset = load_dataset("json", data_files="phi2_linux_prompt_dataset.json")

# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained("microsoft/phi-2", trust_remote_code=True)

tokenizer.pad_token = tokenizer.eos_token

# Tokenize
def tokenize(batch):
    full_texts = [
        f"### Prompt:\n{prompt}\n\n### Response:\n{response}"
        for prompt, response in zip(batch["prompt"], batch["response"])
    ]
    return tokenizer(
        full_texts,
        padding="max_length",
        truncation=True,
        max_length=512,
    )


tokenized_dataset = dataset.map(tokenize, batched=True)


tokenized_dataset = dataset["train"].map(tokenize_function, batched=True)
# Out:
# ...
# Map:   0%|          | 0/100 [00:00<?, ? examples/s]

# %%
print(dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['prompt', 'response'],
#         num_rows: 100
#     })
# })

# %%
trainer.model.save_pretrained("phi2-vinayak-lora")
tokenizer.save_pretrained("phi2-vinayak-lora")
# Out:
# ('phi2-vinayak-lora/tokenizer_config.json',
#  'phi2-vinayak-lora/special_tokens_map.json',
#  'phi2-vinayak-lora/vocab.json',
#  'phi2-vinayak-lora/merges.txt',
#  'phi2-vinayak-lora/added_tokens.json',
#  'phi2-vinayak-lora/tokenizer.json')

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
from peft import PeftModel, PeftConfig

# %%
# Load adapter config
peft_model_path = "phi2-vinayak-lora"
config = PeftConfig.from_pretrained(peft_model_path)

# Load base Phi-2
base_model = AutoModelForCausalLM.from_pretrained(config.base_model_name_or_path)

# Load LoRA weights
model = PeftModel.from_pretrained(base_model, peft_model_path)

# Merge the adapter into base model
merged_model = model.merge_and_unload()

# Save merged model
merged_model.save_pretrained("phi2-merged")
tokenizer = AutoTokenizer.from_pretrained(config.base_model_name_or_path)
tokenizer.save_pretrained("phi2-merged")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
# !zip -r phi2-vinayak-lora.zip phi2-merged
# Out:
#   adding: phi2-merged/ (stored 0%)
#   adding: phi2-merged/config.json (deflated 48%)
#   adding: phi2-merged/generation_config.json (deflated 24%)

# %%
from google.colab import files
files.download("phi2-vinayak-lora")

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
from peft import PeftModel, PeftConfig

# Load your LoRA adapter config
peft_model_path = "phi2-vinayak-lora"
config = PeftConfig.from_pretrained(peft_model_path)

# Load base model
base_model = AutoModelForCausalLM.from_pretrained(config.base_model_name_or_path)
model = PeftModel.from_pretrained(base_model, peft_model_path)

# Merge LoRA with base model
merged_model = model.merge_and_unload()

# ✅ SAVE MODEL + TOKENIZER
merged_model.save_pretrained("phi2-merged")
tokenizer = AutoTokenizer.from_pretrained(config.base_model_name_or_path)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.save_pretrained("phi2-merged")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# WARNING:bitsandbytes.cextension:The installed version of bitsandbytes was compiled without GPU support. 8-bit optimizers and GPU quantization are unavailable.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !zip -r phi2_merged.zip phi2-merged
# Out:
#   adding: phi2-merged/ (stored 0%)
#   adding: phi2-merged/config.json (deflated 48%)
#   adding: phi2-merged/generation_config.json (deflated 24%)

# %%
from google.colab import files
files.download('phi2_merged.zip')

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, TextStreamer
import torch

# Load tokenizer and base model (already merged)
model_path = "phi2-merged"  # if you've moved it to /content in Colab
tokenizer = AutoTokenizer.from_pretrained(model_path, trust_remote_code=True)
model = AutoModelForCausalLM.from_pretrained(model_path, torch_dtype=torch.float16, device_map="auto")

# Set up text streamer (for live output like chat)
streamer = TextStreamer(tokenizer)

# Prompt for testing
prompt = "You are a friendly Linux assistant. How do I list all files in a directory in Linux?"

inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

# Generate a reply
output = model.generate(**inputs, max_new_tokens=100, streamer=streamer)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2-1531583400.py in <cell line: 0>()
#       4 # Load tokenizer and base model (already merged)
#       5 model_path = "phi2-merged"  # if you've moved it to /content in Colab
# ----> 6 tokenizer = AutoTokenizer.from_pretrained(model_path, trust_remote_code=True)
#       7 model = AutoModelForCausalLM.from_pretrained(model_path, torch_dtype=torch.float16, device_map="auto")
#       8
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/tokenization_auto.py in from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#    1067
#    1068             if tokenizer_class_fast and (use_fast or tokenizer_class_py is None):
# -> 1069                 return tokenizer_class_fast.from_pretrained(pretrained_model_name_or_path, *inputs, **kwargs)
#    1070             else:
# ...

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, TextStreamer
import torch

# Use base tokenizer since phi2-merged doesn't have one
base_model = "microsoft/phi-2"
finetuned_path = "/content/phi2-merged"  # Your LoRA merged model path

tokenizer = AutoTokenizer.from_pretrained(base_model, trust_remote_code=True)
model = AutoModelForCausalLM.from_pretrained(finetuned_path, torch_dtype=torch.float16, device_map="auto")

streamer = TextStreamer(tokenizer)

prompt = "You are a Linux assistant. How do I list all files in a directory?"

inputs = tokenizer(prompt, return_tensors="pt").to(model.device)
model.generate(**inputs, max_new_tokens=100, streamer=streamer)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /tmp/ipython-input-3-3747960223.py in <cell line: 0>()
#       7
#       8 tokenizer = AutoTokenizer.from_pretrained(base_model, trust_remote_code=True)
# ----> 9 model = AutoModelForCausalLM.from_pretrained(finetuned_path, torch_dtype=torch.float16, device_map="auto")
#      10
# ...

# %%
ls phi2-merged
# Out:
# config.json  generation_config.json

# %%
from peft import PeftModel
from transformers import AutoModelForCausalLM

# %%
from peft import PeftModel
from transformers import AutoModelForCausalLM

# 1. Load base Phi-2 model
base_model = AutoModelForCausalLM.from_pretrained(
    "microsoft/phi-2",
    torch_dtype=torch.float16,
    device_map="auto"
)

# 2. Load LoRA weights on top of base model
lora_model = PeftModel.from_pretrained(base_model, "/content/phi2-lora")

# 3. Merge LoRA into base model
merged_model = lora_model.merge_and_unload()

# 4. Save the merged model
merged_model.save_pretrained("/content/phi2-merged")
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# HFValidationError                         Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/peft/config.py in _get_peft_type(cls, model_id, **hf_hub_download_kwargs)
#     261             try:
# --> 262                 config_file = hf_hub_download(
#     263                     model_id,
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     105             if arg_name in ["repo_id", "from_id", "to_id"]:
# --> 106                 validate_repo_id(arg_value)
#     107
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_validators.py in validate_repo_id(repo_id)
#     153     if repo_id.count("/") > 1:
# --> 154         raise HFValidationError(
#     155             "Repo id must be in the form 'repo_name' or 'namespace/repo_name':"
#
# ...

# %%
peft_model.save_pretrained("phi2-lora")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-9-2823513278.py in <cell line: 0>()
# ----> 1 peft_model.save_pretrained("phi2-lora")
#
# NameError: name 'peft_model' is not defined

# %%
from peft import PeftModel

lora_model = PeftModel.from_pretrained(base_model, "phi2-lora")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_http.py in hf_raise_for_status(response, endpoint_name)
#     408     try:
# --> 409         response.raise_for_status()
#     410     except HTTPError as e:
#
# /usr/local/lib/python3.11/dist-packages/requests/models.py in raise_for_status(self)
#    1023         if http_error_msg:
# -> 1024             raise HTTPError(http_error_msg, response=self)
#    1025
#
# HTTPError: 401 Client Error: Unauthorized for url: https://huggingface.co/phi2-lora/resolve/main/adapter_config.json
#
# The above exception was the direct cause of the following exception:
#
# RepositoryNotFoundError                   Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/peft/config.py in _get_peft_type(cls, model_id, **hf_hub_download_kwargs)
# ...

# %%
from peft import PeftModel

lora_model = PeftModel.from_pretrained(
    base_model,
    "./phi2-vinayak-lora",   # ✅ Correct path
    is_trainable=False       # or True if you plan to continue training
)

# %%
# !ls ./phi2-vinayak-lora
# Out:
# adapter_config.json	   merges.txt		    tokenizer_config.json
# adapter_model.safetensors  README.md		    tokenizer.json
# added_tokens.json	   special_tokens_map.json  vocab.json

# %%
# Optional: Merge LoRA with base model if needed
lora_model = lora_model.merge_and_unload()

# Save the merged model
lora_model.save_pretrained("phi2-merged")
tokenizer.save_pretrained("phi2-merged")
# Out:
# ('phi2-merged/tokenizer_config.json',
#  'phi2-merged/special_tokens_map.json',
#  'phi2-merged/vocab.json',
#  'phi2-merged/merges.txt',
#  'phi2-merged/added_tokens.json',
#  'phi2-merged/tokenizer.json')

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
from peft import PeftModel

# Load base model (Phi-2 from HuggingFace)
base_model = AutoModelForCausalLM.from_pretrained(
    "microsoft/phi-2",
    device_map="auto"
)

tokenizer = AutoTokenizer.from_pretrained("microsoft/phi-2")

# Load LoRA weights
lora_model = PeftModel.from_pretrained(
    base_model,
    "./phi2-vinayak-lora",   # ✅ Correct local path
    is_trainable=False
)

# Merge LoRA into base model for inference
lora_model = lora_model.merge_and_unload()
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# WARNING:accelerate.big_modeling:Some parameters are on the meta device because they were offloaded to the cpu.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-16-2151626226.py in <cell line: 0>()
#      11
#      12 # Load LoRA weights
# ---> 13 lora_model = PeftModel.from_pretrained(
#      14     base_model,
#      15     "./phi2-vinayak-lora",   # ✅ Correct local path
#
# /usr/local/lib/python3.11/dist-packages/peft/peft_model.py in from_pretrained(cls, model, model_id, adapter_name, is_trainable, config, autocast_adapter_dtype, ephemeral_gpu_offload, low_cpu_mem_usage, key_mapping, **kwargs)
#     553             )
#     554
# --> 555         load_result = model.load_adapter(
#     556             model_id,
#     557             adapter_name,
#
# ...

# %%
from peft import PeftModel
import os

# Create an offload directory
os.makedirs("offload", exist_ok=True)

lora_model = PeftModel.from_pretrained(
    base_model,
    "./phi2-vinayak-lora",
    is_trainable=False,
    device_map="auto",
    offload_folder="offload"  # ✅ NEW LINE to fix the error
)
# Out:
# /usr/local/lib/python3.11/dist-packages/peft/tuners/tuners_utils.py:190: UserWarning: Already found a `peft_config` attribute in the model. This will lead to having multiple adapters in the model. Make sure to know what you are doing!
#   warnings.warn(
# WARNING:accelerate.big_modeling:Some parameters are on the meta device because they were offloaded to the cpu and disk.

# %%
lora_model = lora_model.merge_and_unload()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1-3111921540.py in <cell line: 0>()
# ----> 1 lora_model = lora_model.merge_and_unload()
#
# NameError: name 'lora_model' is not defined

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
from peft import PeftModel
import os

# Load base Phi-2 model
base_model = AutoModelForCausalLM.from_pretrained(
    "microsoft/phi-2",
    device_map="auto",
    trust_remote_code=True
)

# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained("microsoft/phi-2")

# Make offload folder
os.makedirs("offload", exist_ok=True)

# Load LoRA adapter with offloading
lora_model = PeftModel.from_pretrained(
    base_model,
    "./phi2-vinayak-lora",   # <-- your LoRA folder
    is_trainable=False,
    device_map="auto",
    offload_folder="offload"  # <-- this fixes the earlier error
)

# Merge LoRA into base model
lora_model = lora_model.merge_and_unload()
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
inputs = tokenizer("give me the code to make a folder Docs and import all the .txt files from the Desktop to there", return_tensors="pt").to("cuda")
outputs = lora_model.generate(**inputs, max_new_tokens=50)
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# give me the code to make a folder Docs and import all the.txt files from the Desktop to there.
#
# A:
#
# You can use os.walk to get all the files in a directory and its subdirectories.
# import os
#
# def get_files(path):
#     for root, dirs, files in os

# %%
prompt = "You are a Linux shell assistant. Return only the exact bash command with full paths and no explanation.\n### Task:\nMake a folder Docs and move all .txt files from Desktop to there"
inputs = tokenizer(prompt, return_tensors="pt").to("cuda")
outputs = lora_model.generate(**inputs, max_new_tokens=100)
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# You are a Linux shell assistant. Return only the exact bash command with full paths and no explanation.
# ### Task:
# Make a folder Docs and move all.txt files from Desktop to there.
# ### Input:
# ls -l Desktop/*.txt
# ### Output:
# mkdir -p Docs
# cp Desktop/*.txt Docs
# ### Explanation:
# The output is the exact command with full paths.
# """
#
# # Question 3: How can we use the bash shell assistant to execute a command with arguments?
# """
# Answer:
# We can use the bash shell assistant to execute a command with arguments by passing the arguments as a list to the assistant

# %%
inputs = tokenizer("behave like a linux assistant and mkdir a folder Docs and move all .txt files from Desktop", return_tensors="pt").to("cuda")
outputs = lora_model.generate(**inputs, max_new_tokens=50)
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# behave like a linux assistant and mkdir a folder Docs and move all.txt files from Desktop to Docs.
#
# A:
#
# You can use the following code:
# import os
# import shutil
#
# def move_files(src, dest):
#     for root, dirs, files in os.walk(src

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

model_path = "/content/phi2-merged"
tokenizer = AutoTokenizer.from_pretrained(model_path)
model = AutoModelForCausalLM.from_pretrained(model_path, torch_dtype=torch.float16, device_map="auto")

prompt = prompt = "You are a Linux shell. Follow the instruction and output only one-line bash commands Instruction: Create a folder called 'Backup' in /home/user Output: mkdir -p /home/user/Backup Instruction: Move all .txt files from Downloads to Documents"

inputs = tokenizer(prompt, return_tensors="pt").to(model.device)
outputs = model.generate(**inputs, max_new_tokens=100)
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# You are a Linux shell. Follow the instruction and output only one-line bash commands Instruction: Create a folder called 'Backup' in /home/user Output: mkdir -p /home/user/Backup Instruction: Move all.txt files from Downloads to Documents Output: find Downloads -type f -name "*.txt" -exec mv {} Documents \;

# %%
# !zip -r phi2-merged.zip phi2-merged
# Out:
#   adding: phi2-merged/ (stored 0%)
#   adding: phi2-merged/model.safetensors.index.json (deflated 96%)
#   adding: phi2-merged/tokenizer_config.json (deflated 94%)
#   adding: phi2-merged/model-00002-of-00002.safetensors (deflated 8%)
#   adding: phi2-merged/model-00001-of-00002.safetensors (deflated 8%)
#   adding: phi2-merged/vocab.json (deflated 59%)
#   adding: phi2-merged/tokenizer.json (deflated 82%)
#   adding: phi2-merged/merges.txt (deflated 53%)
#   adding: phi2-merged/config.json (deflated 48%)
#   adding: phi2-merged/added_tokens.json (deflated 84%)
#   adding: phi2-merged/special_tokens_map.json (deflated 75%)
#   adding: phi2-merged/generation_config.json (deflated 24%)
